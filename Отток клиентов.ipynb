# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий ревьюера:</b>
#
# Мне понравился твой проект! Спасибо за качественную работу)
# </div>

# %% [markdown]
# Привет, Диана!)
# <br> Меня зовут Дуолан 👋 Буду проверять твой проект. Давай вместе доведем его до идеала 😉
# <br> Дальнейшее общение будет происходить на «ты», если это не вызывает никаких проблем.
# <br> Желательно реагировать на каждый мой комментарий («исправил», «не понятно как исправить ошибку», ...)
# <br> Пожалуйста, не удаляй мои комментарии, они будут необходимы для повторного ревью.
#
# Комментарии будут в <font color='green'>зеленой</font>, <font color='blue'>синей</font> или <font color='red'>красной</font> рамках:
#
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b> Если все сделано отлично
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>⚠️ Совет:</b> Если можно немного улучшить
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>❌ Замечание:</b> Если требуются исправления
# </div>
#
# Работа не может быть принята с красными комментариями.
#
# -------------------
#
# Будет очень хорошо, если ты будешь помечать свои действия следующим образом:
#
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b> ...
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Изменения:</b> Были внесены следующие изменения ...
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; padding: 30px">
# Привет, Дуолан. Спасибо большое за проверку моего проекта, за твои советы и замечания!

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи</a></span></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Проверим-качество-модели-логистической-регрессии,-учитывая-дисбаланс-классов." data-toc-modified-id="Проверим-качество-модели-логистической-регрессии,-учитывая-дисбаланс-классов.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Проверим качество модели логистической регрессии, учитывая дисбаланс классов.</a></span></li><li><span><a href="#Проверим-качество-модели-решающего-дерева,-учитывая-дисбаланс-классов." data-toc-modified-id="Проверим-качество-модели-решающего-дерева,-учитывая-дисбаланс-классов.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Проверим качество модели решающего дерева, учитывая дисбаланс классов.</a></span></li><li><span><a href="#Найдём-лучшие-параметры-для-модели-случайного-леса-с-помощью-модуля-GridSearchCV." data-toc-modified-id="Найдём-лучшие-параметры-для-модели-случайного-леса-с-помощью-модуля-GridSearchCV.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Найдём лучшие параметры для модели случайного леса с помощью модуля GridSearchCV.</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Вам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Постройте модель с предельно большим значением *F1*-меры. Чтобы сдать проект успешно, нужно довести метрику до 0.59. Проверьте *F1*-меру на тестовой выборке самостоятельно.
#
# Дополнительно измеряйте *AUC-ROC*, сравнивайте её значение с *F1*-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠️ Совет:</b>
#
# Важно чтобы в проектах было подробное описание: когда потенциальные работодатели будут смотреть твой проект в портфолио, им нужно будет понимать задачу, чтобы можно было оценить её решение. Вот что можно добавить:
#
# * Описание целей и задачи проекта
# * Описание данных
# * План работы
#
# И рекомендую писать введение от первого лица множественного числа. Так работа выглядит более самостоятельной)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Изменения:</b>
#
# **Цель проекта:** У нас есть данные о поведении клиентов и расторжении договоров с банком. Нам необходимо спрогнозировать уйдёт ли клиент из банка в ближайшее время.
#
# **План работы:** Подготовить и исследовать данные. Посмотреть на баланс классов и построить модели, выбрав лучший метод борьбы с дисбалансом. Найти лучшие параметры для каждой модели и выбрать ту, которая показывает лучший результат F1-меры. Измерять AUC-ROC. Проверить F1 на тестовой выборке, получить метрику не ниже 0.59.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>V2 ✔️ Успешно исправлено</b>
# </div>

# %% [markdown]
# ## Подготовка данных

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import f1_score, confusion_matrix, roc_auc_score, roc_curve, \
                        precision_score, recall_score, make_scorer
from sklearn.utils import shuffle

from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
import warnings

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Импорт выглядит отлично 👍
# </div>

# %%
data = pd.read_csv('/datasets/Churn.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# Удалим столбец с индексом строки, чтобы не путаться в индексах и удалим столбцы с фамилией и id клиента, они не помогут нам в прогнозировании ухода.

# %%
data = data.drop(['RowNumber', 'Surname', 'CustomerId'], axis=1)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Удалить неинформативные признаки - хорошее решение 👍
# </div>

# %% [markdown]
# Приведем названия столбцов к змеиному регистру.

# %%
data=data.rename(columns={'CustomerId':'customer_id', 'CreditScore':'credit_score','Geography':'geography', \
                          'Gender':'gender', 'Age':'age', 'Tenure':'tenure',\
                          'Balance':'balance', 'NumOfProducts':'num_of_products', 'HasCrCard':'has_cr_card',\
                          'IsActiveMember':'is_active_member', 'EstimatedSalary':'estimated_salary', 'Exited':'exited'
                            })

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Работать с такими названиями гораздо удобнее) Посмотри на такой вариант ниже. Здесь мы используем регулярные выражения.
#
# Полезная <a href='https://habr.com/ru/post/545150/'>статья</a> про regex для начала
#
# Этот блогер хорошо объясняет в своем <a href='https://www.youtube.com/watch?v=sHw5hLYFaIw&t=247s'>видео</a>
# </div>
#
# ```python
# df.columns = df.columns.str.replace(r"([A-Z])", r" \1").str.lower().str.replace(' ', '_').str[1:]
# ```

# %% [markdown]
# У нас есть пропуски в столбце tenure, заполним значением -1, чтобы выделить в отдельный класс.

# %%
data['tenure'].value_counts()
# Out:
# 1.0     952
# 2.0     950
# 8.0     933
# 3.0     928
# 5.0     927
# 7.0     925
# 4.0     885
# 9.0     882
# 6.0     881
# 10.0    446
# 0.0     382
# Name: tenure, dtype: int64

# %%
#data['tenure'] = data['tenure'].fillna(data['tenure'].median())
data['tenure'] = data['tenure'].fillna(-1)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Согласен с таким заполнением 👍
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Замечание:</b>
#
# Кодировать данные стоит после разбиения. Так у нас не будет утечки данных.
#
# Подробнее об этом можно прочитать здесь https://datascience.stackexchange.com/questions/108663/why-label-encoding-before-split-is-data-leakage
#
# P.S. после прямого кодирования кол-во столбцов в выборках может отличаться. Тогда лишние признаки можно удалить
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий:</b>
#     Сделала кодирование после разбиения на выборки. Только не поняла, когда преобразовываю массив в датафрейм, как я могу дать названия столбцам примерно через такой код: columns=ohe.categories_ , а не вводя вручную.
#     Так сделать можно только, когда один категориальный признак закодировали, а когда несколько, то как быть?
#
# Второй вопрос: когда надо удалять первые столбцы при кодировании? В теории у нас был пример с полом (там было три варианта-M, F, None), мы сбросили первый и остались M и None. А когда у нас всего два варианта M и F, то все равно надо удалять первый?
#     Если да, то не понимаю, что за случаи, когда первый столбец все же удалить мы не можем.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>V2 Комментарий ревьюера:</b>
#
# Чтобы не попасть в дамми ловушку нужно удалить один из признаков, даже если их всего два)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>V2 ✔️ Успешно исправлено</b>
#
# Молодец, что для кодирования используешь OneHotEncoder() 👍 Он довольно сложный, чем get_dummies
#
# Посмотри на такой вариант:
# </div>
#
# ```python
# cat_columns = features_train.select_dtypes('object').columns
# ohe = OneHotEncoder(drop='first', sparse=False)
# ohe.fit(features_train[cat_columns])
#
# features_train[ohe.get_feature_names()] = pd.DataFrame(ohe.transform(features_train[cat_columns]), columns=ohe.get_feature_names(), index=features_train.index)
# features_valid[ohe.get_feature_names()] = pd.DataFrame(ohe.transform(features_valid[cat_columns]), columns=ohe.get_feature_names(), index=features_valid.index)
# features_test[ohe.get_feature_names()] = pd.DataFrame(ohe.transform(features_test[cat_columns]), columns=ohe.get_feature_names(), index=features_test.index)
#
# features_train.drop(columns=cat_columns, inplace=True)
# features_valid.drop(columns=cat_columns, inplace=True)
# features_test.drop(columns=cat_columns, inplace=True)
# ```

# %% [markdown]
# Разделим фрейм на признаки и целевой признак.

# %%
target = data['exited']
features = data.drop(['exited'], axis=1)

# %% [markdown]
# Разделим обучающую и валидационную выборки.

# %%
features_train, features_valid, target_train, target_valid = train_test_split( 
            features, target, test_size=0.4, random_state=12345)

# %% [markdown]
# Разделим валидационную выборку на валидационную и тестовую.

# %%
features_valid, features_test, target_valid, target_test = train_test_split( 
            features_valid, target_valid, test_size=0.5, random_state=12345)

# %% [markdown]
# Проверим размеры выборок.

# %%
print('Обучающая:', features_train.shape, target_train.shape)
print('Валидационная:', features_valid.shape, target_valid.shape)
print('Тестовая:', features_test.shape, target_test.shape)
# Out:
# Обучающая: (6000, 10) (6000,)
# Валидационная: (2000, 10) (2000,)
# Тестовая: (2000, 10) (2000,)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Данные поделены верно, пропорции выбраны адекватные 👍
# </div>

# %%
features_train.head()
# Out:
#       credit_score geography  gender  age  tenure    balance  num_of_products  \
# 7479           567     Spain    Male   35     8.0  153137.74                1
# 3411           711    France  Female   37     8.0  113899.92                1
# 6027           850   Germany    Male   44     3.0  140393.65                2
# 1247           512    France    Male   24     6.0       0.00                2
# 3716           665   Germany  Female   27     2.0  147435.96                1
#
#       has_cr_card  is_active_member  estimated_salary
# 7479            1                 0          88659.07
# 3411            0                 0          80215.20
# 6027            0                 1         186285.52
# 1247            1                 0          37654.31
# 3716            0                 0         187508.06

# %% [markdown]
# Преобразуем категориальные признаки техникой прямого кодирования. Кодировать нам понадобится только страну и пол.

# %%
cat_columns = features_train.select_dtypes('object').columns
ohe = OneHotEncoder(drop='first', sparse=False)
ohe.fit(features_train[cat_columns])
# Out:
# OneHotEncoder(drop='first', sparse=False)

# %%
# %%capture --no-display

features_train[ohe.get_feature_names()] = pd.DataFrame(ohe.transform(features_train[cat_columns]), columns=ohe.get_feature_names(), index=features_train.index)
features_valid[ohe.get_feature_names()] = pd.DataFrame(ohe.transform(features_valid[cat_columns]), columns=ohe.get_feature_names(), index=features_valid.index)
features_test[ohe.get_feature_names()] = pd.DataFrame(ohe.transform(features_test[cat_columns]), columns=ohe.get_feature_names(), index=features_test.index)

# %%
# %%capture --no-display

features_train.drop(columns=cat_columns, inplace=True)
features_valid.drop(columns=cat_columns, inplace=True)
features_test.drop(columns=cat_columns, inplace=True)

# %%
features_train.head()
# Out:
#       credit_score  age  tenure    balance  num_of_products  has_cr_card  \
# 7479           567   35     8.0  153137.74                1            1
# 3411           711   37     8.0  113899.92                1            0
# 6027           850   44     3.0  140393.65                2            0
# 1247           512   24     6.0       0.00                2            1
# 3716           665   27     2.0  147435.96                1            0
#
#       is_active_member  estimated_salary  x0_Germany  x0_Spain  x1_Male
# 7479                 0          88659.07         0.0       1.0      1.0
# 3411                 0          80215.20         0.0       0.0      0.0
# 6027                 1         186285.52         1.0       0.0      1.0
# 1247                 0          37654.31         0.0       0.0      1.0
# 3716                 0         187508.06         1.0       0.0      0.0

# %%
#ohe = OneHotEncoder(handle_unknown='ignore')
#features_train_ohe = ohe.fit_transform(f_train[['geography', 'gender']])

# кодируем эти данные в валидационной и тестовой выборках
# features_valid_ohe = ohe.transform(f_valid[['geography', 'gender']])
# features_test_ohe = ohe.transform(f_test[['geography', 'gender']])

# %% [markdown]
# Посмотрим названия столбцов массива с категориальными данными, какие выявил кодировщик, чтобы, преобразуя массив в датафрейм, передать их в правильной последовательности.

# %%
# ohe.categories_

# %%
# # преобразуем массив в датафрейм
# train_ohe = pd.DataFrame(features_train_ohe.toarray(), columns=
#              ['geo_France', 'geo_Germany', 'geo_Spain','gender_Female', 'gender_Male'])

# # присоединяем кодированные данные к иcходному датафрейму, удалив исходные категориальные столбцы                     
# features_train = pd.concat(
#     [f_train.drop(['geography', 'gender'], axis=1).reset_index(drop=True), train_ohe], axis=1)

# features_train.head()

# %%
# f_train.head()

# %%
# присоединяем кодированные данные к иcходному датафрейму, удалив исходные категориальные столбцы 
# f_train = f_train.join(pd.DataFrame(features_train_ohe.toarray(), columns=
#              ['geo_France', 'geo_Germany', 'geo_Spain','gender_Female', 'gender_Male']))

# f_train.head()

# %% [markdown]
# То же самое делаем с валидационной выборкой.

# %%
# # преобразуем массив в датафрейм
# valid_ohe = pd.DataFrame(features_valid_ohe.toarray(), columns=
#              ['geo_France', 'geo_Germany', 'geo_Spain','gender_Female', 'gender_Male'])

# # присоединяем кодированные данные к иcходному датафрейму, удалив исходные категориальные столбцы                     
# features_valid = pd.concat(
#     [f_valid.drop(['geography', 'gender'], axis=1).reset_index(drop=True), valid_ohe], axis=1)

# features_valid.head()

# %% [markdown]
# И с тестововй.

# %%
# # преобразуем массив в датафрейм
# test_ohe = pd.DataFrame(features_test_ohe.toarray(), columns=
#              ['geo_France', 'geo_Germany', 'geo_Spain','gender_Female', 'gender_Male'])

# # присоединяем кодированные данные к иcходному датафрейму, удалив исходные категориальные столбцы                     
# features_test = pd.concat(
#     [f_test.drop(['geography', 'gender'], axis=1).reset_index(drop=True), test_ohe], axis=1)

# features_test.head()

# %% [markdown]
# Сбросим индексы в таргете, чтобы дальше не было конфликта при работе функций по увеличению/уменьшению выборок в борьбе с дисбалансом.

# %%
# target_train = target_train.reset_index(drop=True)

# %%
# target_valid = target_valid.reset_index(drop=True)

# %%
# target_test = target_test.reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий:</b>
# Дуолан, подскажи, можно было как то объединить таблицы методом concat, не сбрасывая индексы? И не влияют ли одинаковые индексы в разных выборках на качество моделей?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>V2 Комментарий ревьюера:</b>
#
# Выше написал свой вариант) Там без сбрасывания индексов
# </div>

# %% [markdown]
# Масштабируем признаки баланс на счете и предполагаемая зарплата.

# %%
warnings.filterwarnings('ignore')

numeric = ['credit_score', 'age', 'balance', 'tenure', 'num_of_products', 'estimated_salary']

scaler = StandardScaler()
scaler.fit(features_train[numeric])

features_train[numeric] = scaler.transform(features_train[numeric])
features_valid[numeric] = scaler.transform(features_valid[numeric])
features_test[numeric] = scaler.transform(features_test[numeric])

#pd.options.mode.chained_assignment = None
display(features_train.head())
# Out:
#       credit_score       age    tenure   balance  num_of_products  \
# 7479     -0.886751 -0.373192  1.083651  1.232271        -0.891560
# 3411      0.608663 -0.183385  1.083651  0.600563        -0.891560
# 6027      2.052152  0.480939 -0.452862  1.027098         0.830152
# 1247     -1.457915 -1.417129  0.469046 -1.233163         0.830152
# 3716      0.130961 -1.132419 -0.760164  1.140475        -0.891560
#
#       has_cr_card  is_active_member  estimated_salary  x0_Germany  x0_Spain  \
# 7479            1                 0         -0.187705         0.0       1.0
# 3411            0                 0         -0.333945         0.0       0.0
# 6027            0                 1          1.503095         1.0       0.0
# 1247            1                 0         -1.071061         0.0       0.0
# 3716            0                 0          1.524268         1.0       0.0
#
#       x1_Male
# 7479      1.0
# 3411      0.0
# 6027      1.0
# 1247      1.0
# 3716      0.0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Отлично, признаки масштабированы 👍 Не забыли, что fit нужно делать только на train выборке.
# </div>

# %% [markdown]
# **Проверим наши признаки на мультиколлинеарность.**

# %%
correlation_matrix = features_train.corr()
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(correlation_matrix, annot = True);

# %% [markdown]
# <div style="border:solid blue 2px; padding: 30px">
# Мы заполнили пропуски, удалили столбцы, не имеющие значение для нашего исследования, закодировали категориальные данные и масштабировали признаки.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Ты хорошо владеешь методами первичного анализа данных 👍
# </div>

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# Посмотрим на баланс классов.

# %%
print(target.value_counts())
target.value_counts(normalize=True).plot(kind='bar');
# Out:
# 0    7963
# 1    2037
# Name: exited, dtype: int64

# %% [markdown]
# **У нас наблюдается дисбаланс классов, отрицательного почти в 4 раза больше.**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Виден явный дисбаланс классов в пользу отрицательного класса. Если мы будем всех людей прогнозировать, что они не уйдут из банка, то в 80% случаев мы будем правы.
# </div>

# %% [markdown]
# Создадим модель логистической регрессии без учета дисбаланса и обучим её.

# %%
model_logistic_dis = LogisticRegression(random_state=12345)
model_logistic_dis.fit(features_train, target_train);

# %% [markdown]
# **Создадим функцию для просчета метрик R2, F1 и AUC-ROC. На вход функция получает модель, признаки и целевой признак, а возвращает метрики.**

# %%
def print_metrics(model, features, target):
    predict = model.predict(features) # предказания модели
    proba = model.predict_proba(features)[:, 1] # вероятность положительного класса

# найдем долю правильных ответов R2
    print('R2:', model.score(features, target))

# найдем среднее гармоническое полноты и точности F1
    print(f'F1: {round(f1_score(target, predict), 5)}')

# найдем значение AUC-ROC (покажет как сильно наша модель отличается от случайной)
    print(f'AUC-ROC: {round(roc_auc_score(target, proba), 5)}')

# %%
# Узнаем метрики нашей модели логистической регрессии.
print_metrics(model_logistic_dis, features_valid, target_valid)
# Out:
# R2: 0.8025
# F1: 0.3339
# AUC-ROC: 0.75868

# %% [markdown]
# **У модели доля правильных ответов составляет 80%, но правильно предсказывает положительный класс она в 33% случаев.**
#
# Обучим модель случайного леса также без учета дисбаланса.

# %%
model_forest_dis = RandomForestClassifier(random_state=12345)
model_forest_dis.fit(features_train, target_train)

# Узнаем метрики нашей модели решающего дерева
print_metrics(model_forest_dis, features_valid, target_valid)
# Out:
# R2: 0.8605
# F1: 0.59031
# AUC-ROC: 0.84191

# %% [markdown]
# **У модели случайного леса F1-мера больше на 0.23, а AUC-ROC на 0.08.**

# %% [markdown]
# <div style="border:solid blue 2px; padding: 30px">
# На этом этапе мы выяснили, что положительного класса у нас в 4 раза меньше и обучили модель, не учитывая дисбаланс классов. Она показала плохие результаты F1 у логистической регрессии всего 0.33. А вот у модели случайного леса F1  0.56, а AUC-ROC 0.83.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Замечание:</b>
#
# Можешь добавить обучение еще одной модели в обучении без учета дисбаланса?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий:</b>
# Добавила обучение модели решающего дерева.
#
# Обновила вывод:
#
# <div style="border:solid blue 2px; padding: 30px">
# На этом этапе мы выяснили, что положительного класса у нас в 4 раза меньше и обучили две модели, не учитывая дисбаланс классов. Модель логистической регрессии показала плохие результаты F1, всего 0.33. А вот модель решающего дерева F1 показала лучше, но дала низкий результат AUC-ROC.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>V2 ✔️ Успешно исправлено</b>
# </div>

# %% [markdown]
# ## Борьба с дисбалансом

# %% [markdown]
# Теперь построим модель логистической регресии, но сбалансируем классы с помощью параметра "class weight = 'balanced'".

# %%
model_logistic = LogisticRegression(class_weight='balanced', solver='liblinear', random_state=12345)
model_logistic.fit(features_train, target_train)

# Узнаем метрики нашей модели логистической регрессии с балансом классов
print_metrics(model_logistic, features_valid, target_valid)
# Out:
# R2: 0.701
# F1: 0.48889
# AUC-ROC: 0.76347

# %%
model_forest = RandomForestClassifier(class_weight='balanced', random_state=12345)
model_forest.fit(features_train, target_train)

# Узнаем метрики модели решающего дерева с балансом классов
print_metrics(model_forest, features_valid, target_valid)
# Out:
# R2: 0.8575
# F1: 0.56489
# AUC-ROC: 0.84355

# %% [markdown]
# **F1-мера у логистической регрессии увеличилась на 0.15, а у случаного леса стала немного хуже.**
#
#
# Теперь посмотрим значения метрик, увеличив положительный класс в 4 раза с помощью функции upsample.

# %%
def upsample(features, target, repeat):
    # отберем в разные переменные признаки, относящиеся к классу 0 и к классу 1
    features_zeros = features[target == 0] 
    features_ones = features[target == 1]
    # также разделим целевой признак по классам
    target_zeros = target[target == 0]
    target_ones = target[target == 1]
    # соединим таблицы с разными классами в общие переменные
    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    # перемешаем наши данные
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=12345)
    
    # функция возвращает наши новые таблицы с признаками и целевым признаком
    return features_upsampled, target_upsampled

features_train_upsampled, target_train_upsampled = upsample(features_train, target_train, 4)
print(features_train_upsampled.shape) # проверим размер таблицы признаков
print(target_train_upsampled.shape) # проверим размер таблицы целевого признака
# Out:
# (9588, 11)
# (9588,)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Увеличение выборки выполнено верно - классы сбалансированы 👍
# </div>

# %% [markdown]
# Обучим модель на новых признаках.

# %%
model_logistic_up = LogisticRegression(solver='liblinear', random_state=12345)
model_logistic_up.fit(features_train_upsampled, target_train_upsampled)

# Узнаем метрики нашей модели логистической регрессии с балансом классов
print_metrics(model_logistic_up, features_valid, target_valid)
# Out:
# R2: 0.7005
# F1: 0.4876
# AUC-ROC: 0.7634

# %%
model_forest_up = RandomForestClassifier(random_state=12345)
model_forest_up.fit(features_train_upsampled, target_train_upsampled)

# Узнаем метрики модели решающего дерева с балансом классов
print_metrics(model_forest_up, features_valid, target_valid)
# Out:
# R2: 0.8495
# F1: 0.59705
# AUC-ROC: 0.83738

# %% [markdown]
# **Результат у первой модели совсем немного хуже, чем в предыдущем варианте, где мы сбалансировали вес классов с помощью параметров. А у леса F1 такой же, как при дисбалансе.**
#
# Теперь сбалансируем, создав функцию по уменьшению отрицательного класса по тому же принципу, но здесь мы задаем значение frac.

# %%
def downsample(features, target, fraction):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_downsampled = pd.concat(
        [features_zeros.sample(frac=fraction, random_state=12345)] + [features_ones])
    target_downsampled = pd.concat(
        [target_zeros.sample(frac=fraction, random_state=12345)] + [target_ones])
    
    features_downsampled, target_downsampled = shuffle(
        features_downsampled, target_downsampled, random_state=12345)
    
    return features_downsampled, target_downsampled

# %% [markdown]
# Зададим переменной frac значение 0.25 - доля класса 0, которая нам нужна, чтобы сравняться с классом 1.

# %%
features_downsampled, target_downsampled = downsample(features_train, target_train, 0.25)

# обучим модель на новых признаках
model_logistic_down = LogisticRegression(solver='liblinear', random_state=12345)
model_logistic_down.fit(features_downsampled, target_downsampled)

# Узнаем метрики нашей модели логистической регрессии с балансом классов
print_metrics(model_logistic_down, features_valid, target_valid)
# Out:
# R2: 0.703
# F1: 0.48969
# AUC-ROC: 0.7627

# %% [markdown]
# **Доля правильных ответов и F1 немного лучше, чем при дисбалансе классов и при увеличении положительного класса.**

# %%
model_forest_down = RandomForestClassifier(random_state=12345)
model_forest_down.fit(features_downsampled, target_downsampled)

# Узнаем метрики решающего дерева с балансом классов
print_metrics(model_forest_down, features_valid, target_valid)
# Out:
# R2: 0.7795
# F1: 0.58357
# AUC-ROC: 0.84454

# %% [markdown]
# **Доля правильных ответов ниже, чем при дисбалансе классов, но метрики стали лучше.**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Уменьшение выборки тоже выполнено верно 👍
# </div>

# %% [markdown]
# Теперь найдем порог классификации, при котором F1 максимально высокое.

# %%
# выделим вероятности положительного класса
probabilities_one_valid = model_logistic_dis.predict_proba(features_valid)[:, 1]

# создадим переменные для сравнения с лучшими результатами
max_f1 = 0
threshold_best = 0
pre = 0
re = 0

# создадим функцию по подбору порога для максимизации F1
for threshold in np.arange(0, 1, 0.02):
    predicted_valid = probabilities_one_valid > threshold
    precision = precision_score(target_valid, predicted_valid)
    recall = recall_score(target_valid, predicted_valid)
    f1 = f1_score(target_valid, predicted_valid)
    if f1 > max_f1:
        max_f1 = f1
        threshold_best = threshold
        pre = precision
        re = recall

# выводим лучший результат        
print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}, F1 = {:.3f}".format(
        threshold_best, pre, re, max_f1))
# Out:
# Порог = 0.26 | Точность = 0.433, Полнота = 0.589, F1 = 0.499

# %% [markdown]
# Сбалансируем классы по полученному порогу и посмотрим на метрики.

# %%
model_logistic = LogisticRegression(class_weight={0: 0.26, 1:0.74}, solver='liblinear', random_state=12345)
model_logistic.fit(features_train, target_train)

# Узнаем метрики нашей модели логистической регрессии с балансом классов
print_metrics(model_logistic, features_valid, target_valid)
# Out:
# R2: 0.7545
# F1: 0.49949
# AUC-ROC: 0.7626

# %% [markdown]
# **Доля правильных ответов и F1 немного лучше, чем при дисбалансе классов и при увеличении положительного класса.**

# %%
# выделим вероятности положительного класса
probabilities_one_valid = model_forest_dis.predict_proba(features_valid)[:, 1]

# создадим переменные для сравнения с лучшими результатами
max_f1 = 0
threshold_best = 0
pre = 0
re = 0

# создадим функцию по подбору порога для максимизации F1
for threshold in np.arange(0, 1, 0.02):
    predicted_valid = probabilities_one_valid > threshold
    precision = precision_score(target_valid, predicted_valid)
    recall = recall_score(target_valid, predicted_valid)
    f1 = f1_score(target_valid, predicted_valid)
    if f1 > max_f1:
        max_f1 = f1
        threshold_best = threshold
        pre = precision
        re = recall

# выводим лучший результат        
print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}, F1 = {:.3f}".format(
        threshold_best, pre, re, max_f1))
# Out:
# Порог = 0.30 | Точность = 0.587, Полнота = 0.663, F1 = 0.622

# %% [markdown]
# Сбалансируем классы по полученному порогу и посмотрим на метрики.

# %%
model_forest = RandomForestClassifier(class_weight={0: 0.34, 1:0.66}, random_state=12345)
model_forest.fit(features_train, target_train)

# Узнаем метрики нашей модели логистической регрессии с балансом классов
print_metrics(model_forest, features_valid, target_valid)
# Out:
# R2: 0.859
# F1: 0.56748
# AUC-ROC: 0.83888

# %% [markdown]
# **Доля правильных ответов осталась такой же, а метрики стали ниже, чем при дисбалансе классов.**

# %% [markdown]
# <div style="border:solid blue 2px; padding: 30px">
#       Доля правильно предсказанных ответов у модели логистической регрессии, учитывающей дисбаланс классов с помощью порога классификации стала на 0.05 ниже, чем с дисбалансом, но метрика F1 увеличилась с 0.33 до 0.497.
#
#
# У леса результаты почти не отличаются с балансом и дисбалансом классов, улучшенный результат показала увеличенная выборка и cass_weight='balanced'.
# Продолжим работать с балансом классов с помощью гиперпараметра class_weight.

# %% [markdown]
# ### Проверим качество модели логистической регрессии, учитывая дисбаланс классов.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий:</b>
# Дуолан, как можно убрать эти красные предупреждения? Почему не помогает warnings.filterwarnings('ignore')
# ?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>V2 Комментарий ревьюера:</b>
#
# Здесь приведены несколько способов https://softhints.com/turn-off-warnings-jupyterlab-jupyter-notebook/
# </div>

# %% [markdown]
# Подберем лучшие параметры для нашей модели, используя модуль GridSearchCV.

# %%
with warnings.catch_warnings():
    model_grid_logistic = GridSearchCV(
    LogisticRegression(class_weight='balanced', solver='liblinear', random_state=12345),
                param_grid = {'penalty': ('l1', 'l2', 'elasticnet'), # какие параметры подбираем
                'C': np.logspace(-4, 3, 10),
                'max_iter': range(1, 101, 5)},
    scoring=make_scorer(f1_score), # метрика, по которой будем оценивать модель
    n_jobs=2, # параллельная оценка разных комбинаций параметров
    return_train_score=True)
    
    model_grid_logistic.fit(features_train, target_train);
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/conda/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/conda/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/conda/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# ...

# %%
# выводим результаты
print(f'Лучший результат F1: {round(model_grid_logistic.best_score_, 5)}')
print('Модель для лучшего F1: {}'.format(model_grid_logistic.best_estimator_))
# Out:
# Лучший результат F1: 0.5072
# Модель для лучшего F1: LogisticRegression(C=0.021544346900318846, class_weight='balanced', max_iter=6,
#                    penalty='l1', random_state=12345, solver='liblinear')

# %% [markdown]
# Обучим модель логистической регресии с подобранными лучшими параметрами, учитывая дисбаланс классов.

# %%
model_logistic = LogisticRegression(C=0.021544346900318846, class_weight='balanced', max_iter=6,
                   penalty='l1', random_state=12345, solver='liblinear')

model_logistic.fit(features_train, target_train);

# %% [markdown]
# Выводим на экран результаты метрик логистической регресии.

# %%
print('Метрики модели логистической регрессии:')
print_metrics(model_logistic, features_valid, target_valid)
# Out:
# Метрики модели логистической регрессии:
# R2: 0.7175
# F1: 0.49599
# AUC-ROC: 0.76908

# %% [markdown]
# ### Проверим качество модели решающего дерева, учитывая дисбаланс классов.

# %% [markdown]
# Найдём лучшие параметы модели.

# %%
# %%time

warnings.filterwarnings('ignore')

model_grid_tree = GridSearchCV(
    DecisionTreeClassifier(class_weight='balanced', random_state=12345),
              param_grid = { 'criterion': ('gini', 'entropy', 'log_loss'),
                'max_depth': range (1, 11, 1),
                'min_samples_leaf': range (1, 5, 1) },
    scoring=make_scorer(f1_score),
    n_jobs=2)
    
model_grid_tree.fit(features_train, target_train);
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/conda/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 898, in fit
#     super().fit(
#   File "/opt/conda/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 347, in fit
#     criterion = CRITERIA_CLF[self.criterion](self.n_outputs_,
# KeyError: 'log_loss'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ...

# %%
# выводим результаты
print(f'Лучший результат F1: {round(model_grid_tree.best_score_, 5)}')
print('Модель для лучшего F1: {}'.format(model_grid_tree.best_estimator_))
# Out:
# Лучший результат F1: 0.56306
# Модель для лучшего F1: DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=6, min_samples_leaf=2, random_state=12345)

# %%
# обучаем модель по нашим лучшим параметрам
model_tree = DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
                       max_depth=6, min_samples_leaf=2, random_state=12345)
model_tree.fit(features_train, target_train)
predict_valid = model_tree.predict(features_valid)

# выводим результаты метрик
print('Метрики модели решающего дерева:')
print_metrics(model_tree, features_valid, target_valid)
# Out:
# Метрики модели решающего дерева:
# R2: 0.759
# F1: 0.5642
# AUC-ROC: 0.82278

# %% [markdown]
# ### Найдём лучшие параметры для модели случайного леса с помощью модуля GridSearchCV.

# %%
# %%time

warnings.filterwarnings('ignore')

model_grid_forrest = GridSearchCV(
    RandomForestClassifier(class_weight='balanced', random_state=12345),
    param_grid = { 'n_estimators': range (10, 101, 20),
                   'max_depth': range (1,12, 2) },
    scoring=make_scorer(f1_score),
    n_jobs=2,
    return_train_score=True)
    
model_grid_forrest.fit(features_train, target_train);
# Out:
# CPU times: user 763 ms, sys: 74.7 ms, total: 838 ms
# Wall time: 35.3 s
# GridSearchCV(estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=12345),
#              n_jobs=2,
#              param_grid={'max_depth': range(1, 12, 2),
#                          'n_estimators': range(10, 101, 20)},
#              return_train_score=True, scoring=make_scorer(f1_score))

# %%
print(f'Лучший результат F1: {round(model_grid_forrest.best_score_, 5)}')
print('Модель для лучшего F1: {}'.format(model_grid_forrest.best_estimator_))
# Out:
# Лучший результат F1: 0.61301
# Модель для лучшего F1: RandomForestClassifier(class_weight='balanced', max_depth=9, n_estimators=90,
#                        random_state=12345)

# %% [markdown]
# **Мы получили лучшую максимальную глубину 9, а количество деревьев = 90. Обучим модель с этими параметрами.**

# %%
model_forrest_best = RandomForestClassifier(class_weight='balanced', max_depth=9,
                       n_estimators=90, random_state=12345)
model_forrest_best.fit(features_train, target_train)
predict_valid_forrest = model_forrest_best.predict(features_valid)

print('Метрики лучшей модели случайного леса:')
print_metrics(model_forrest_best, features_valid, target_valid)
# Out:
# Метрики лучшей модели случайного леса:
# R2: 0.8325
# F1: 0.62061
# AUC-ROC: 0.85348

# %% [markdown]
# <div style="border:solid blue 2px; padding: 30px">
# Эта модель получила наилучшие метрики.

# %% [markdown]
# <div style="border:solid blue 2px; padding: 30px">
# Мы сравнили три модели. Метрики у случайного леса лучше, чем у остальных моделей.
# Наша лучшая модель имеет максимальную глубину 9 и количество деревьев - 90.
# Правильных ответов у нашей модели 83%, среднее гаромоническое точности и полноты 0.619, а площадь под кривой ROC 0.85.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Модели обучены корректно 👍 Молодец, что для подбора гиперпараметров используешь GridSearchCV
# </div>

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# Проведем финальное тестирование нашей лучшей модели на тестовой выборке.

# %%
predict_test_forrest = model_forrest_best.predict(features_test)
print('F1:', f1_score(target_test, predict_test_forrest))
# Out:
# F1: 0.6165919282511212

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Отличный результат 👍
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠️ Совет:</b>
#
# Здесь можно визуализировать ROC-кривую лучшей модели.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Изменения:</b>
# Построиим нашу ROC-кривую.

# %%
probabilities_one_valid = model_forrest_best.predict_proba(features_valid)[:, 1] # вероятность положительного класса

fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid)

plt.figure()

# ROC-кривая случайной модели 
plt.plot([0, 1], [0, 1], linestyle='--')
plt.plot(fpr, tpr)

# утановим границы осей от 0 до 1
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

# подпишем оси
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

# добавим к графику заголовок
plt.title('ROC-кривая')
plt.show()

# %%
x_ax = range(len(features_test))
plt.scatter(x_ax, target_test, s=5, color="blue", label="original")
plt.plot(x_ax, predict_test_forrest, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px">
#
# <div class="alert alert-info">  <b>Итог исследования:<b> </div>
#
# Мы изучили и подготовили наши данные, избавившись от пропусков и ненужных данных, которые не влияют на нашу задачу - это индекс строки, фамилия и id клиента. Затем мы закодировали категориальные данные - страна проживания и пол, после чего провели масштабирование признаков, чтобы модель при обучении все признаки расценивала, как равнозначные.
#
# На следующем этапе мы исследовали баланс классов. Отрицательный класс оказался в 4 раза больше положительного. При обучении модели без учёта дисбаланса классов мы получили очень низкое значение F1-меры у логистической регрессии(0.33).
#
# Затем эту же модель мы обучили на сбалансированных разными методами классах. Лучшие результаты показал метод балансировки через параметр class_weight. Балансировка классов у модели случайного леса дала незначительное улучшение результатов.
#
# В ходе исследования мы сравнили три модели, подбирая для каждой лучшие гиперпараметры с помощью модуля GridSearchCV. Наиучшие результаты получились у случайного леса.
# Наша лучшая модель имеет максимальную глубину 9 и количество деревьев - 90.
# Правильных ответов у нашей модели 83%, среднее гаромоническое точности и полноты 0.619, а площадь под кривой ROC 0.85.
#
# В конце нашей работы мы проверили нашу модель на тестовой выборке и получили результат F1 = 0.61 и построили ROC-кривую лучшей модели.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Вывод соответствует исследованию 👍
# </div>

# %% [markdown]
# # <font color='orange'>Общее впечатление</font>
# * Этот проект выполнен очень хорошо
# * Видно, что приложено много усилий
# * Молодец, что структурируешь ноутбук, приятно проверять такие работы
# * У тебя чистый и лаконичный код
# * Мне было интересно читать твои промежуточные выводы
# * Твой уровень подачи материала находится на высоком уровне
# * Исправь, пожалуйста, мои замечания. Затем отправляй на повторную проверку
# * Жду новую версию проекта 👋

# %% [markdown]
# # <font color='orange'>2. Общее впечатление</font>
# * Спасибо за быстрое внесение правок
# * Теперь проект выглядит лучше )
# * Критических замечаний нет
# * Молодец, отличная работа!
# * Надеюсь, ревью было полезным
# * Удачи в дальнейшем обучении 👋

# %% [markdown]
# # <font color='orange'>Рекомендации 🔥</font>
# * Анализ данных на python и pandas https://www.youtube.com/watch?v=dd3RcafdOQk&t=82s
# * Курс "Введение в машинное обучение" https://stepik.org/course/4852
# * Разумные способы кодирования категориальных данных для машинного обучения https://machinelearningmastery.ru/smarter-ways-to-encode-categorical-data-for-machine-learning-part-1-of-3-6dca2f71b159/
# * Статья про "непонятную" метрику ROC-AUC https://dyakonov.org/2017/07/28/auc-roc-площадь-под-кривой-ошибок/
# * Хочешь подтянуть математику для DS?) https://academy.stepik.org/math-for-data-science
# * Результаты обучения моделей можно визуализировать 😎 https://www.datatechnotes.com/2019/08/elasticnet-regression-example-in-python.html
# * В нашем деле нужно быть всегда в курсе всех новинок, новостей и тд, вот тут публикуют новости в области DS: https://www.infoq.com/data-analysis/news/
# * Всем аналитикам данных рекомендую книгу Даниела Канемана "Думай медленно, решай быстро"

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Выполнен шаг 1: данные подготовлены
# - [x]  Выполнен шаг 2: задача исследована
#     - [x]  Исследован баланс классов
#     - [x]  Изучены модели без учёта дисбаланса
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 3: учтён дисбаланс
#     - [x]  Применено несколько способов борьбы с дисбалансом
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 4: проведено тестирование
# - [x]  Удалось достичь *F1*-меры не менее 0.59
# - [x]  Исследована метрика *AUC-ROC*
